# %% [raw]
# Se importa la libreria pandas:

# %%
import pandas as pd

# %% [raw]
# Apertura y lectura del documento con read:

# %%
df = pd.read_csv('Inmuebles_Disponibles_Para_La_Venta.csv')

# %% [raw]
# usamos info para poder mostrar informacion concisa sobre el DataFrame de Inmuebles disponibles para la venta:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 448 entries, 0 to 447
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Codigo                  448 non-null    int64
#  1   Ciudad                  448 non-null    object
#  2   Departamento            448 non-null    object
#  3   Barrio                  59 non-null     object
#  4   Direccion               448 non-null    object
#  5   Area Terreno            448 non-null    int64
#  6   Area Construida         448 non-null    int64
#  7   Detalle Disponibilidad  448 non-null    object
#  8   Estrato                 448 non-null    object
#  9   Precio                  448 non-null    int64
#  10  Tipo de Inmueble        448 non-null    object
#  11  Datos Adicionales       77 non-null     object
# dtypes: int64(4), object(8)
# memory usage: 42.1+ KB

# %% [raw]
# df.isnull().sum()  esta variable identifica columnas con nulos

# %%
df.isnull().sum()
# Out:
# Codigo                      0
# Ciudad                      0
# Departamento                0
# Barrio                    389
# Direccion                   0
# Area Terreno                0
# Area Construida             0
# Detalle Disponibilidad      0
# Estrato                     0
# Precio                      0
# Tipo de Inmueble            0
# Datos Adicionales         371
# dtype: int64

# %% [markdown]
# No se van a eliminar ningun registro vacio toda vez que es posible que afecte las demas columnas
# sin embargo para eliminar los datos seria
# df = df.dropna()

# %%
df.head(10)
# Out:
#    Codigo     Ciudad  Departamento                       Barrio  \
# 0    2330     BOGOTA  CUNDINAMARCA                SANTA MATILDE
# 1    2363     BOGOTA  CUNDINAMARCA                      TINTALA
# 2    2575   SOGAMOSO        BOYACÁ                       CENTRO
# 3    2669  LA CALERA  CUNDINAMARCA                    LA CALERA
# 4    4408     BOGOTA  CUNDINAMARCA                         SUBA
# 5    5017   RICAURTE  CUNDINAMARCA  CONDOMINIO CAMPESTRE MONACO
# 6    5287     BOGOTA  CUNDINAMARCA                          NaN
# 7    5616       CHIA  CUNDINAMARCA              VEREDA FONQUETA
# 8    7394    BITUIMA  CUNDINAMARCA           VEREDA DE CAMBULAR
# 9    7539      TENJO  CUNDINAMARCA                          NaN
#
#                                            Direccion  Area Terreno  \
# 0  CL 10 SUR # 34B-24 LT 2 MZ X-46 (SANTA MATILDE...        559804
# 1  KR 84 CON CL 10 LT # 8 DE SAN JUAN DE CASTILLA...        302079
# ...

# %% [raw]
# Utilizamos sort_values para ordenar la informacion por el dato de precio con el fin de que sea de menor a mayor

# %%
Precio = df.sort_values("Precio", ascending = True)
Precio.head(10)
# Out:
#      Codigo         Ciudad Departamento           Barrio  \
# 383   18851      CARTAGENA      BOLÍVAR              NaN
# 49    17337        PEREIRA    RISARALDA  AV 30 DE AGOSTO
# 316   18447  VILLAVICENCIO         META              NaN
# 48    17336        PEREIRA    RISARALDA  AV 30 DE AGOSTO
# 116   18137  VILLAVICENCIO         META              NaN
# 108   18121  VILLAVICENCIO         META              NaN
# 107   18120  VILLAVICENCIO         META              NaN
# 106   18119  VILLAVICENCIO         META              NaN
# 105   18118  VILLAVICENCIO         META              NaN
# 104   18117  VILLAVICENCIO         META              NaN
#
#                                              Direccion  Area Terreno  \
# 383  KILÓMETRO 4  DE LA VÍA MAMONAL  CARRERA 56, #6...             0
# 49   CL 69  O ACCESO A CUBA  AV 30 DE AGOSTO  LOTE ...             0
# 316  CENTRAL MINORISTA DE ABASTOS DE VILLAVICENCIO ...             0
# ...

# %% [raw]
# Utilizamos sort_values para ordenar la informacion por el dato de precio con el fin de que sea de mayor a menos

# %%
Precio = df.sort_values("Precio", ascending = False)
Precio.head(10)
# Out:
#      Codigo    Ciudad     Departamento             Barrio  \
# 13    11409      BUGA  VALLE DEL CAUCA  VEREDA CHAMBIMBAL
# 68    17510    BOGOTA     CUNDINAMARCA                NaN
# 44    17180    BOGOTA     CUNDINAMARCA                NaN
# 73    17745    BOGOTA     CUNDINAMARCA                NaN
# 437   19292    BOGOTA     CUNDINAMARCA                NaN
# 438   19292    BOGOTA     CUNDINAMARCA                NaN
# 2      2575  SOGAMOSO           BOYACÁ             CENTRO
# 4      4408    BOGOTA     CUNDINAMARCA               SUBA
# 0      2330    BOGOTA     CUNDINAMARCA      SANTA MATILDE
# 10     7541    MADRID     CUNDINAMARCA                NaN
#
#                                              Direccion  Area Terreno  \
# 13   LT A1-A24 B1-B79 C1-C51 D1-D9 STA ROSA LT1-46 ...     321719700
# 68                                DG 48J SUR N° 1A  50             0
# 44                           AV CR 7 NO. 166 - 51 LT B             0
# ...

# %%
rangosPrecios = [0,125725000000, 7134100500000,452337898200000]

# %%
nombresRangos = ["Bajos","Medios","Altos"]

# %%
df['Rango_Precios'] = pd.cut(df['Precio'], rangosPrecios, labels = nombresRangos)

# %% [raw]
# Obtendremos categorias segun los rangos especificados en Altos, Medios y Bajos:

# %%
df.head(100)
# Out:
#     Codigo         Ciudad  Departamento         Barrio  \
# 0     2330         BOGOTA  CUNDINAMARCA  SANTA MATILDE
# 1     2363         BOGOTA  CUNDINAMARCA        TINTALA
# 2     2575       SOGAMOSO        BOYACÁ         CENTRO
# 3     2669      LA CALERA  CUNDINAMARCA      LA CALERA
# 4     4408         BOGOTA  CUNDINAMARCA           SUBA
# ..     ...            ...           ...            ...
# 95   18089  VILLAVICENCIO          META            NaN
# 96   18090  VILLAVICENCIO          META            NaN
# 97   18091  VILLAVICENCIO          META            NaN
# 98   18092  VILLAVICENCIO          META            NaN
# 99   18109  VILLAVICENCIO          META            NaN
#
#                                             Direccion  Area Terreno  \
# 0   CL 10 SUR # 34B-24 LT 2 MZ X-46 (SANTA MATILDE...        559804
# 1   KR 84 CON CL 10 LT # 8 DE SAN JUAN DE CASTILLA...        302079
# 2   CRA. 10 #11- 78/80 Ó CL 12 # 9 - 77/85 Ó CALLE...        165508
# ...

# %% [raw]
# con la funcion describe() obtendremos valores estadisticos por parte del precio de los predios, los cuales nos ayudara en la interpretacion de los datos.

# %%
estadisticoPorPrecios = df['Precio'].describe()

# %%
print(estadisticoPorPrecios)
# Out:
# count    4.480000e+02
# mean     9.372906e+12
# std      3.817964e+13
# min      0.000000e+00
# 25%      1.257250e+11
# 50%      1.652050e+11
# 75%      1.861440e+12
# max      4.523379e+14
# Name: Precio, dtype: float64

# %%
df['Precio'].describe()
# Out:
# count    4.480000e+02
# mean     9.372906e+12
# std      3.817964e+13
# min      0.000000e+00
# 25%      1.257250e+11
# 50%      1.652050e+11
# 75%      1.861440e+12
# max      4.523379e+14
# Name: Precio, dtype: float64

# %% [raw]
# se usa la funcion unique() en los departamentos con el fin de saber cuantos departamentos hay, y con esto poder generar mas adelante un total por areas contruidas y por precios

# %%
listado_AreaNombres = print(df['Departamento'].unique())
# Out:
# ['CUNDINAMARCA' 'BOYACÁ' 'ATLÁNTICO' 'VALLE DEL CAUCA' 'CAUCA' 'CALDAS'
#  'NORTE DE SANTANDER' 'TOLIMA' 'RISARALDA' 'META' 'BOLÍVAR' 'CASANARE'
#  'SANTANDER' 'ANTIOQUIA' 'CÓRDOBA']

# %% [raw]
# Realizamos un Histograma de los valores en Precios:

# %%
df['Precio'].hist(bins=10,figsize=(10,5))
# Out:
# <Axes: >

# %%
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
sns.histplot(df.Precio,color="b",bins=30,kde=True)
plt.show()

# %% [raw]
# Crearemos un grafico de torta Entre las Departamentos actuales y sus precios, importaremos matplotlib, primero quitaremos los precios que esten en 0 y adicionalmente los departamentos que esten vacios

# %%
import matplotlib.pyplot as plt

# %%
df_filtrado = df[(df['Precio'] != 0) & (df['Departamento'] != '')]

# %%
df_filtrado = df[(df['Departamento'] != '')]

# %%
df_agregado = df_filtrado.groupby('Departamento')['Precio'].sum().reset_index()

# %%
plt.pie(df_agregado['Precio'], labels=df_agregado['Departamento'], autopct='%1.1f%%', startangle=100, pctdistance=0.85)
plt.axis('equal')
plt.show()

# %% [raw]
# Eliminaremos datos de areas contruidas y de terrenos y de precios con el fin de generar una cercania a lo real en cuanto areas y precio, todo lo que este en 0 y cumpla con la condicional "&" se eliminara:

# %%
df = df.drop(df[(df['Area Terreno'] == 0) & (df['Area Construida'] == 0) & (df['Precio'] == 0)].index)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 447 entries, 0 to 447
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Codigo                  447 non-null    int64
#  1   Ciudad                  447 non-null    object
#  2   Departamento            447 non-null    object
#  3   Barrio                  59 non-null     object
#  4   Direccion               447 non-null    object
#  5   Area Terreno            447 non-null    int64
#  6   Area Construida         447 non-null    int64
#  7   Detalle Disponibilidad  447 non-null    object
#  8   Estrato                 447 non-null    object
#  9   Precio                  447 non-null    int64
#  10  Tipo de Inmueble        447 non-null    object
#  11  Datos Adicionales       76 non-null     object
#  12  Rango_Precios           447 non-null    category
# dtypes: category(1), int64(4), object(8)
# memory usage: 46.0+ KB

# %%
df = df.drop(df[(df['Area Terreno'] == 0) & (df['Area Construida'] == 0)].index)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25 entries, 0 to 34
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Codigo                  25 non-null     int64
#  1   Ciudad                  25 non-null     object
#  2   Departamento            25 non-null     object
#  3   Barrio                  24 non-null     object
#  4   Direccion               25 non-null     object
#  5   Area Terreno            25 non-null     int64
#  6   Area Construida         25 non-null     int64
#  7   Detalle Disponibilidad  25 non-null     object
#  8   Estrato                 25 non-null     object
#  9   Precio                  25 non-null     int64
#  10  Tipo de Inmueble        25 non-null     object
#  11  Datos Adicionales       18 non-null     object
#  12  Rango_Precios           25 non-null     category
# dtypes: category(1), int64(4), object(8)
# memory usage: 2.7+ KB

# %%
Precio = df.sort_values("Precio", ascending = False)
Precio.head(100)
# Out:
#     Codigo                  Ciudad     Departamento  \
# 13   11409                    BUGA  VALLE DEL CAUCA
# 2     2575                SOGAMOSO           BOYACÁ
# 4     4408                  BOGOTA     CUNDINAMARCA
# 0     2330                  BOGOTA     CUNDINAMARCA
# 5     5017                RICAURTE     CUNDINAMARCA
# 14   11786              VILLA RICA            CAUCA
# 24   12120        CALIMA EL DARIEN  VALLE DEL CAUCA
# 1     2363                  BOGOTA     CUNDINAMARCA
# 21   12117        CALIMA EL DARIEN  VALLE DEL CAUCA
# 7     5616                    CHIA     CUNDINAMARCA
# 18   12114        CALIMA EL DARIEN  VALLE DEL CAUCA
# 17   12113        CALIMA EL DARIEN  VALLE DEL CAUCA
# 16   12112        CALIMA EL DARIEN  VALLE DEL CAUCA
# 20   12116        CALIMA EL DARIEN  VALLE DEL CAUCA
# 25   12121        CALIMA EL DARIEN  VALLE DEL CAUCA
# 12   11335                    CALI  VALLE DEL CAUCA
# 15   11787  SANTANDER DE QUILICHAO            CAUCA
# ...

# %%
df['Precio'].hist(bins = 20, figsize  = (10,10))
# Out:
# <Axes: >

# %%
df['Area Construida'].hist(bins = 20, figsize  = (10,10))
# Out:
# <Axes: >

# %%
df['Area Terreno'].hist(bins = 20, figsize  = (10,10))
# Out:
# <Axes: >

# %% [raw]
# se va a volver a realizar un diagrama de torta en el cual podremos ver realmente que datos en las dos areas estan completos y esto se pueda determinar en valor Precio
# Solo 25 Codigos de todo el listado cumple con las caracteristicas de Area terreno, Area construccion y precio

# %%
import matplotlib.pyplot as plt

# %%
df_filtrado = df[(df['Precio'] != 0) & (df['Departamento'] != '')]

# %%
df_agregado = df_filtrado.groupby('Departamento')['Precio'].sum().reset_index()

# %%
plt.pie(df_agregado['Precio'], labels=df_agregado['Departamento'], autopct='%1.1f%%', startangle=100, pctdistance=0.85)
plt.axis('equal')
plt.show()

# %%
df['Precio'].describe()
# Out:
# count    2.500000e+01
# mean     5.516221e+13
# std      9.403412e+13
# min      4.916800e+11
# 25%      9.094862e+12
# 50%      2.406650e+13
# 75%      5.171324e+13
# max      4.523379e+14
# Name: Precio, dtype: float64

# %%
import matplotlib.pyplot as plt

# %%
df1 = df.drop(df[(df['Area Terreno'] == 0) & (df['Area Construida'] == 0)].index)

# %%
df2 = df1.groupby('Departamento')['Area Terreno'].sum().reset_index()

# %%
plt.pie(df2['Area Terreno'], labels=df2['Departamento'], autopct='%1.1f%%', startangle=10, pctdistance=0.55)
plt.axis('equal')
plt.show()

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25 entries, 0 to 34
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Codigo                  25 non-null     int64
#  1   Ciudad                  25 non-null     object
#  2   Departamento            25 non-null     object
#  3   Barrio                  24 non-null     object
#  4   Direccion               25 non-null     object
#  5   Area Terreno            25 non-null     int64
#  6   Area Construida         25 non-null     int64
#  7   Detalle Disponibilidad  25 non-null     object
#  8   Estrato                 25 non-null     object
#  9   Precio                  25 non-null     int64
#  10  Tipo de Inmueble        25 non-null     object
#  11  Datos Adicionales       18 non-null     object
#  12  Rango_Precios           25 non-null     category
# dtypes: category(1), int64(4), object(8)
# memory usage: 2.7+ KB
